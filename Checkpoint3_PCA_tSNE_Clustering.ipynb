# %% [markdown]
# # Dataset

# %%
data <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_READ_FPKM.csv", header=TRUE, sep=",")
data_READ <- as.matrix(data) #READ Rectum adenocarcinoma: 4min to read

# %%
data2 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_BRCA_FPKM.csv", header=TRUE, sep=",")
data_BRCA <- as.matrix(data2) # BRCA Breast invasive carcinoma: 6min to read

# %%
data3 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_BLCA_FPKM.csv", header=TRUE, sep=",")
data_BLCA <- as.matrix(data3) # BLCA Bladder Urothelial Carcinoma: 3min to read

# %%
data4 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_CESC_FPKM.csv", header=TRUE, sep=",")
data_CESC <- as.matrix(data4) # CESC Cervical squamous cell carcinoma and endocervical adenocarcinoma: 2min to read

# %%
#data5 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_CHOL_FPKM.csv", header=TRUE, sep=",")
#data_CHOL <- as.matrix(data5) # CHOL Cholangiocarcinoma: min to read
#### VERIFY DATASET

# %%
data6 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_COAD_FPKM.csv", header=TRUE, sep=",")
data_COAD <- as.matrix(data6) # COAD Colon adenocarcinoma: min to read

# %%
#data7 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_ESCA_FPKM.csv", header=TRUE, sep=",")
#data_ESCA <- as.matrix(data7) # ESCA Esophageal carcinoma: min to read
#### VERIFY DATASET

# %%
data8 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_GBM_FPKM.csv", header=TRUE, sep=",")
data_GBM <- as.matrix(data8) # GBM Glioblastoma multiforme: 3min to read

# %%
data9 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_HNSC_FPKM.csv", header=TRUE, sep=",")
data_HNSC <- as.matrix(data9) # HNSC Head and Neck squamous cell carcinoma: 3min to read

# %%
data10 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_KICH_FPKM.csv", header=TRUE, sep=",")
data_KICH <- as.matrix(data10) # KICH Kidney Chromophobe: 3min to read

# %%
data11 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_KIRC_FPKM.csv", header=TRUE, sep=",")
data_KIRC <- as.matrix(data11) # KIRC Kidney renal clear cell carcinoma: 4min to read

# %%
data12 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_KIRP_FPKM.csv", header=TRUE, sep=",")
data_KIRP <- as.matrix(data12) # KIRP Kidney renal papillary cell carcinoma: 4min to read

# %%
data13 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_LIHC_FPKM.csv", header=TRUE, sep=",")
data_LIHC <- as.matrix(data13) # LIHC Liver hepatocellular carcinoma: 2min to read

# %%
data14 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_LUAD_FPKM.csv", header=TRUE, sep=",")
data_LUAD <- as.matrix(data14) # LUAD Lung adenocarcinoma: 3min to read

# %%
data15 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_LUSC_FPKM.csv", header=TRUE, sep=",")
data_LUSC <- as.matrix(data15) # LUSC Lung squamous cell carcinoma: 3min to read

# %%
#data16 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_PAAD_FPKM.csv", header=TRUE, sep=",")
#data_PAAD <- as.matrix(data16) # PAAD Pancreatic adenocarcinoma: min to read
### VERIFY DATASET

# %%
#data17 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_PCPG_FPKM.csv", header=TRUE, sep=",")
#data_PCPG <- as.matrix(data17) # PCPG Pheochromocytoma and Paraganglioma: min to read
### VERIFY DATASET

# %%
data18 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_PRAD_FPKM.csv", header=TRUE, sep=",")
data_PRAD <- as.matrix(data18) # PRAD Prostate adenocarcinoma: 2min to read

# %%
#data19 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_SARC_FPKM.csv", header=TRUE, sep=",")
#data_SARC <- as.matrix(data19) # SARC Sarcoma: min to read
### VERIFY DATASET

# %%
data20 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_SKCM_FPKM.csv", header=TRUE, sep=",")
data_SKCM <- as.matrix(data20) # SKCM Skin Cutaneous Melanoma: 3min to read

# %%
data21 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_STAD_FPKM.csv", header=TRUE, sep=",")
data_STAD <- as.matrix(data21) # STAD Stomach adenocarcinoma: 3min to read

# %%
data22 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_THCA_FPKM.csv", header=TRUE, sep=",")
data_THCA <- as.matrix(data22) # THCA Thyroid carcinoma: 3min to read

# %%
#data23 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_THYM_FPKM.csv", header=TRUE, sep=",")
#data_THYM <- as.matrix(data23) # THYM Thymoma: min to read
###VERIFY DATASET

# %%
data24 <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Tumor_UCEC_FPKM.csv", header=TRUE, sep=",")
data_UCEC <- as.matrix(data24) # UCEC Uterine Corpus Endometrial Carcinoma: 2min to read

# %%
dim(data_READ)
dim(data_BRCA)
dim(data_BLCA)
dim(data_CESC)
#dim(data_CHOL)
dim(data_COAD)
#dim(data_ESCA)
dim(data_GBM)
dim(data_HNSC)
dim(data_KICH)
dim(data_KIRC)
dim(data_KIRP)
dim(data_LIHC)
dim(data_LUAD)
dim(data_LUSC)
#dim(data_PAAD)
#dim(data_PCPG)
dim(data_PRAD)
#dim(data_SARC)
dim(data_SKCM)
dim(data_STAD)
dim(data_THCA)
#dim(data_THYM)
dim(data_UCEC)
# Out:
# [1]   167 23370
# [1]  1119 23370
# [1]   414 23370
# [1]   306 23370
# [1]   483 23370
# [1]   170 23370
# [1]   504 23370
# [1]    66 23370
# [1]   542 23370
# [1]   291 23370
# [1]   374 23370
# [1]   541 23370
# [1]   502 23370
# [1]   502 23370
# [1]   472 23370
# [1]   420 23370
# [1]   513 23370
# [1]   554 23370

# %%
C<-rbind(data_READ[1:nrow(data_READ),1:ncol(data_READ)], 
         data_BRCA[1:nrow(data_BRCA),1:ncol(data_BRCA)], 
         data_BLCA[1:nrow(data_BLCA),1:ncol(data_BLCA)],
         data_CESC[1:nrow(data_CESC),1:ncol(data_CESC)],
         data_COAD[1:nrow(data_COAD),1:ncol(data_COAD)],
         data_GBM[1:nrow(data_GBM),1:ncol(data_GBM)],
         data_HNSC[1:nrow(data_HNSC),1:ncol(data_HNSC)],
         data_KICH[1:nrow(data_KICH),1:ncol(data_KICH)],
         data_KIRC[1:nrow(data_KIRC),1:ncol(data_KIRC)],
         data_KIRP[1:nrow(data_KIRP),1:ncol(data_KIRP)], 
         data_LIHC[1:nrow(data_LIHC),1:ncol(data_LIHC)], 
         data_LUAD[1:nrow(data_LUAD),1:ncol(data_LUAD)],
         data_LUSC[1:nrow(data_LUSC),1:ncol(data_LUSC)],
         data_PRAD[1:nrow(data_PRAD),1:ncol(data_PRAD)],
         data_SKCM[1:nrow(data_SKCM),1:ncol(data_SKCM)],
         data_STAD[1:nrow(data_STAD),1:ncol(data_STAD)],
         data_THCA[1:nrow(data_THCA),1:ncol(data_THCA)],
         data_UCEC[1:nrow(data_UCEC),1:ncol(data_UCEC)])
#18 types of cancer
write.csv(C, file = "C:/Users/isabel/Documents/BENG213_Dataset/CSV/C.csv")

# %%
dim(C)
# Out:
# [1]  7940 23370

# %% [markdown]
# # PCA

# %%
install.packages(c("FactoMineR", "factoextra"))
# Out:
# package 'FactoMineR' successfully unpacked and MD5 sums checked
# package 'factoextra' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\isabel\AppData\Local\Temp\RtmpqStmRe\downloaded_packages

# %%
library("FactoMineR")
library("factoextra")
# Out:
# Loading required package: ggplot2
# Welcome! Related Books: `Practical Guide To Cluster Analysis in R` at https://goo.gl/13EFCZ

# %%
#Z_new<-matrix(data = C[,-1:-2], nrow = nrow(C[,-1:-2]), ncol = ncol(C[,-1:-2]), byrow = TRUE)
#write.csv(Z_new, file = "C:/Users/isabel/Documents/BENG213_Dataset/CSV/Z_new.csv")

# %%
C <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/C.csv",sep=",",row.names=1)

# %%
#Z_new2<-as.matrix(C[,-1:-2])
#write.csv(Z_new, file = "C:/Users/isabel/Documents/BENG213_Dataset/CSV/Z_new2.csv")
# Out:
# Error in C[, -1:-2]: object of type 'closure' is not subsettable
# Traceback:
#
# 1. as.matrix(C[, -1:-2])

# %%
#PCA_data <- read.csv("C:/Users/isabel/Documents/BENG213_Dataset/CSV/Z_new.csv",sep=",",row.names=1)

# %%
C.pca <- PCA(C[, -1:-2], graph = FALSE)

# %%
ind.p <- fviz_pca_ind(C.pca, geom = "point", col.ind = C[,"Tumor.Type"])
ggpubr::ggpar(ind.p,
              title = "Principal Component Analysis",
              subtitle = "TCGA data set",
              caption = "Source: factoextra",
              xlab = "PC1", ylab = "PC2",
              legend.title = "Tumor Type", legend.position = "top",
              ggtheme = theme_gray(), palette = "jco"
              )
# Out:
# Warning message:
# "This manual palette can handle a maximum of 10 values. You have supplied 18."Warning message:
# "The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 18. Consider
# specifying shapes manually if you must have them."Warning message:
# "Removed 4944 rows containing missing values (geom_point)."Warning message:
# "Removed 12 rows containing missing values (geom_point)."
# plot without title

# %%
fviz_pca_ind(C.pca,
             geom.ind = "point", # show points only (nbut not "text")
             col.ind = C[,"Tumor.Type"], # color by groups
             #palette = c("#00AFBB", "#E7B800", "#FC4E07"),
             addEllipses = TRUE, # Concentration ellipses
             xlim=c(-200,200), 
             ylim=c(-100, 100),
             legend.title = "Tumor Type"
             )
# Out:
# plot without title

# %%
# Contributions of variables to PC1
fviz_contrib(C.pca, choice = "var", axes = 1, top = 10)
# Out:
# plot without title

# %%
# Contributions of variables to PC2
fviz_contrib(C.pca, choice = "var", axes = 2, top = 10)
# Out:
# plot without title

# %%
var <- get_pca_var(C.pca)

# %%
var$coord
# Out:
#              Dim.1        Dim.2         Dim.3        Dim.4       Dim.5
# X1.2.SBSRNA4  0.276615570 -0.2535694134  0.586280332  0.10462813  0.0008481844
# A1BG         -0.247497974 -0.2140629804 -0.273662316  0.23138475 -0.2135191522
# A1BG.AS1     -0.080084452 -0.2132422797 -0.203590919  0.08497794 -0.0488241042
# A1CF         -0.138203735 -0.2533858326 -0.354275586  0.33821178 -0.2533821325
# A2LD1        -0.059181467 -0.0839747734 -0.027769368  0.13508716 -0.1837734902
# A2M           0.018892608 -0.2952795923 -0.254496255  0.02802646  0.1252170996
# A2ML1        -0.067039459  0.2166602482 -0.221255717 -0.02223372  0.0887625838
# A2MP1         0.080689608 -0.0049243136  0.054030018  0.13068066  0.0354481469
# A4GALT       -0.145309432 -0.0002175681  0.033973247  0.06619175  0.2185512824
# A4GNT         0.059276505 -0.0090521936 -0.052800619  0.11190199  0.0132682007
# AA06          0.215293738  0.0291041564  0.020481926  0.28207539  0.0240270838
# AAA1          0.205151992  0.0894971421 -0.031251810  0.36169899 -0.0687578626
# AAAS         -0.248439845  0.1585167738  0.614932301  0.07002831  0.1069167829
# AACS         -0.039656459  0.3204235150  0.099862920 -0.13242336 -0.1873315823
# AACSP1        0.051258868 -0.0519974470  0.105772880  0.12011491  0.1425178022
# AADAC        -0.202056652 -0.1780341234 -0.273087467  0.21554882 -0.2203161961
# AADACL2       0.047683711  0.1191926661 -0.046802970  0.03754738  0.0647836240
# AADACL3      -0.003958430  0.0134932533 -0.018673197  0.00347444  0.0160700620
# AADACL4       0.003473962  0.0133444437  0.045137444  0.06108505  0.0160762043
# AADAT         0.051291228 -0.0401437238  0.318456100 -0.02980061 -0.2711860907
# AAGAB         0.209870640  0.3520576648  0.165644984 -0.32692299 -0.2596321362
# AAK1          0.547246057 -0.1295802727  0.026680256  0.13048200 -0.0614290676
# AAMP         -0.264711905  0.1834499067  0.382406093 -0.18621647 -0.1349841532
# AANAT         0.102255746  0.0534811174  0.070780219  0.26132197  0.3780413159
# AARS         -0.058388816  0.1063494851  0.073828619 -0.21454512  0.0600587070
# AARS2         0.003782676  0.1274625976  0.234667237 -0.00823765  0.1860036967
# AARSD1       -0.355958650 -0.0789198593  0.533852708  0.07230657 -0.0191918538
# AASDH         0.563294385  0.0792951409  0.126272433 -0.24373915 -0.0900695774
# AASDHPPT      0.388991999 -0.0003774423  0.015140332 -0.22477650  0.1022466663
# AASS          0.151513283 -0.2446671373  0.004041647  0.10801368  0.0641353610
# ...          ...          ...           ...          ...         ...
# ZSCAN2        0.256831972 -0.27196951    0.30750321  -0.11357128 -0.22030835
# ZSCAN20       0.602234365  0.21451507   -0.01386274  -0.05724265  0.11518231
# ZSCAN21       0.253732223 -0.06387306    0.33813631  -0.19591502  0.12563387
# ZSCAN22       0.226897196  0.16882973    0.24472424  -0.14768790  0.09935920
# ZSCAN23       0.565507760 -0.09180148    0.14186014   0.11937027 -0.01606810
# ZSCAN29       0.569398471  0.27976425    0.14434476  -0.11065992 -0.02076281
# ZSCAN30       0.538453685 -0.29463105    0.40092213  -0.07894773  0.14588508
# ZSCAN4        0.042962562  0.01989548    0.07345286   0.08105631  0.01966061
# ZSCAN5A       0.010169049  0.26667506    0.20694388  -0.01852986  0.11884473
# ZSCAN5B      -0.006170967  0.04696714    0.06388254   0.03633392  0.02633068
# ZSWIM1       -0.004670719  0.31599946    0.41122938   0.07369211 -0.05795768
# ZSWIM2        0.165774753  0.02156269    0.07336901   0.16297740  0.11390037
# ZSWIM3        0.058998606  0.22635459    0.24941041   0.01138459 -0.12041162
# ZSWIM4        0.018628360  0.21703441    0.15890358   0.02673089  0.23718049
# ZSWIM5        0.242850199 -0.30343768    0.12529617  -0.01882582 -0.11784916
# ZSWIM6        0.543612025  0.02000789    0.08423194   0.07615859  0.10786435
# ZSWIM7       -0.048837749 -0.40766682    0.51864761  -0.03713488  0.11265856
# ZUFSP         0.363688266  0.45829903    0.12825971  -0.07185667 -0.07777587
# ZW10          0.294553720  0.55381850   -0.06302385  -0.16916780 -0.08796018
# ZWILCH        0.181388173  0.74579445    0.02401718  -0.09301905  0.06288999
# ZWINT        -0.060427993  0.70520363    0.16415572  -0.04946733  0.03521370
# ZXDA          0.687695777 -0.21451869    0.01332712  -0.01566480 -0.11405597
# ZXDB          0.470076736  0.03942127   -0.04252003  -0.07473330 -0.33807885
# ZXDC          0.600662747  0.19623711    0.18561957   0.16018106  0.01931334
# ZYG11A        0.218728605  0.17409645    0.15090126  -0.07630607 -0.12381065
# ZYG11B        0.682517644 -0.26361749   -0.04779335  -0.02534189 -0.04847341
# ZYX          -0.209072601  0.08022582   -0.02430486   0.06718941  0.37625975
# ZZEF1         0.518800087  0.02707143   -0.01405443   0.04359241  0.05977710
# ZZZ3          0.639390288  0.15408100    0.05243090  -0.17040589 -0.08392810
# tAKR         -0.081585465 -0.15750115   -0.24254064   0.32234938 -0.20030891

# %%
# Create a grouping variable using kmeans
# Create 3 groups of variables (centers = 3)
set.seed(123)
res.km <- kmeans(var$coord, centers = 3, nstart = 1)
grp <- as.factor(res.km$cluster)
# Color variables by groups
fviz_pca_var(C.pca, col.var = grp, 
             #palette = c("#0073C2FF", "#EFC000FF", "#868686FF"),
             legend.title = "Cluster")
# Out:
# plot without title

# %%
print(C.pca)
# Out:
# **Results for the Principal Component Analysis (PCA)**
# The analysis was performed on 7940 individuals, described by 23368 variables
# *The results are available in the following objects:
#
#    name               description
# 1  "$eig"             "eigenvalues"
# 2  "$var"             "results for the variables"
# 3  "$var$coord"       "coord. for the variables"
# 4  "$var$cor"         "correlations variables - dimensions"
# 5  "$var$cos2"        "cos2 for the variables"
# 6  "$var$contrib"     "contributions of the variables"
# 7  "$ind"             "results for the individuals"
# 8  "$ind$coord"       "coord. for the individuals"
# 9  "$ind$cos2"        "cos2 for the individuals"
# 10 "$ind$contrib"     "contributions of the individuals"
# 11 "$call"            "summary statistics"
# 12 "$call$centre"     "mean of the variables"
# 13 "$call$ecart.type" "standard error of the variables"
# 14 "$call$row.w"      "weights for the individuals"
# 15 "$call$col.w"      "weights for the variables"

# %% [markdown]
# # tSNE

# %%
library(caret)  
library(Rtsne)

# %%
tsne_data <- as.matrix(C[, -1:-2])

# %%
tsne_model = Rtsne(tsne_data,check_duplicates=FALSE, pca=TRUE, perplexity=30, theta=0.5, dims=2)

# %%
d_tsne_1 = as.data.frame(tsne_model$Y)

# %%
## plotting the results without clustering
ggplot(d_tsne_1, aes(x=V1, y=V2)) +  
  geom_point(size=0.25) +
  guides(colour=guide_legend(override.aes=list(size=6))) +
  xlab("") + ylab("") +
  ggtitle("t-SNE") +
  theme_light(base_size=20) +
  theme(axis.text.x=element_blank(),
        axis.text.y=element_blank()) +
  scale_colour_brewer(palette = "Set2")
# Out:
# plot without title

# %%
install.packages("randomcoloR")
# Out:
# also installing the dependency 'V8'
# package 'V8' successfully unpacked and MD5 sums checked
# package 'randomcoloR' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\isabel\AppData\Local\Temp\RtmpqStmRe\downloaded_packages

# %%
library(randomcoloR)

# %%
n <- 20
palette1 <- distinctColorPalette(n)

# %%
##Creating the cluster models
##Next piece of code will create the k-means and hierarchical cluster models. 
#To then assign the cluster number (1, 2 or 3) to which each input case belongs.

## keeping original data
d_tsne_1_original=d_tsne_1

## Creating k-means clustering model, and assigning the result to the data used to create the tsne
fit_cluster_kmeans=kmeans(scale(d_tsne_1), 18)  
d_tsne_1_original$cl_kmeans = factor(fit_cluster_kmeans$cluster)

## Creating hierarchical cluster model, and assigning the result to the data used to create the tsne
fit_cluster_hierarchical=hclust(dist(scale(d_tsne_1)))

## setting 3 clusters as output
d_tsne_1_original$cl_hierarchical = factor(cutree(fit_cluster_hierarchical, k=18))  

#Plotting the cluster models onto t-SNE output
#Now time to plot the result of each cluster model, based on the t-SNE map.

plot_cluster=function(data, var_cluster, palette)  
{
  ggplot(data, aes_string(x="V1", y="V2", color=var_cluster)) +
  geom_point(size=0.25) +
  guides(colour=guide_legend(override.aes=list(size=6))) +
  xlab("") + ylab("") +
  ggtitle("") +
  theme_light(base_size=20) +
  theme(axis.text.x=element_blank(),
        axis.text.y=element_blank(),
        legend.direction = "horizontal", 
        legend.position = "bottom",
        legend.box = "horizontal") + 
    scale_colour_manual(values=palette) 
}


plot_k=plot_cluster(d_tsne_1_original, "cl_kmeans", palette1)  
plot_h=plot_cluster(d_tsne_1_original, "cl_hierarchical", palette1)

## and finally: putting the plots side by side with gridExtra lib...
library(gridExtra)  
grid.arrange(plot_k, plot_h,  ncol=2)
# Out:
# plot without title

# %%
plot_cluster(d_tsne_1_original, "cl_kmeans", palette1)
# Out:
# plot without title

# %%
plot_cluster(d_tsne_1_original, "cl_hierarchical", palette1)
# Out:
# plot without title

# %%
plot(d_tsne_1,col=C[,"Tumor.Type"])
# Out:
# plot without title

# %%
library(ggplot2)
tsne_plot <- data.frame(x = d_tsne_1[,1], y = d_tsne_1[,2], col = C[,"Tumor.Type"])
ggplot(tsne_plot) + geom_point(aes(x=x, y=y, color=col))
# Out:
# plot without title
